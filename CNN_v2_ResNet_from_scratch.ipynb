# %% [markdown]
# # CNN from Scratch v2 — ResNet-style for CIFAR-10
#
# **Goal**: Reach 88–92% on CIFAR-10, competitive with Xception transfer learning.
#
# **Key upgrades from v1**:
# - Residual (skip) connections — enables 20+ layers without degradation
# - Batch Normalization throughout — faster convergence, higher LR
# - Per-channel normalization of inputs
# - Cosine LR decay with warm-up + SGD momentum (vs flat Adam)
# - Label smoothing regularization
# - Global Average Pooling instead of Flatten

# %% [markdown]
# ### 1. Install & imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import math

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.19.0

# %% [markdown]
# ### 2. Load & preprocess CIFAR-10

# %%
(x_train_full, y_train_full), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

x_train_full = x_train_full.astype("float32") / 255.0
x_test       = x_test.astype("float32") / 255.0

# Per-channel normalization (important — helps ResNets converge faster)
mean = np.mean(x_train_full, axis=(0, 1, 2))
std  = np.std(x_train_full,  axis=(0, 1, 2))
x_train_full = (x_train_full - mean) / std
x_test       = (x_test - mean) / std

x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.1, random_state=42
)
print(f"Train: {x_train.shape}, Val: {x_val.shape}, Test: {x_test.shape}")
# Out:
# Train: (45000, 32, 32, 3), Val: (5000, 32, 32, 3), Test: (10000, 32, 32, 3)

# %% [markdown]
# ### 3. Data augmentation pipeline (applied at train time only)

# %%
augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomTranslation(0.1, 0.1),   # random crop equivalent
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    # Mixup / CutMix can be added as a custom layer for +1-2% more
], name="augmentation")

# %% [markdown]
# ### 4. Residual block (the core building block)

# %%
def residual_block(x, filters, stride=1, name="res"):
    """
    Pre-activation residual block (He et al. 2016 v2):
    BN → ReLU → Conv → BN → ReLU → Conv + skip connection
    """
    shortcut = x

    # First conv
    x = tf.keras.layers.BatchNormalization(name=f"{name}_bn1")(x)
    x = tf.keras.layers.Activation("relu", name=f"{name}_relu1")(x)
    x = tf.keras.layers.Conv2D(filters, 3, strides=stride, padding="same",
                               use_bias=False, name=f"{name}_conv1")(x)
    # Second conv
    x = tf.keras.layers.BatchNormalization(name=f"{name}_bn2")(x)
    x = tf.keras.layers.Activation("relu", name=f"{name}_relu2")(x)
    x = tf.keras.layers.Conv2D(filters, 3, padding="same",
                               use_bias=False, name=f"{name}_conv2")(x)

    # Adjust shortcut if shape changed (stride or filter count mismatch)
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = tf.keras.layers.Conv2D(filters, 1, strides=stride,
                                          padding="same", use_bias=False,
                                          name=f"{name}_proj")(shortcut)

    return tf.keras.layers.Add(name=f"{name}_add")([x, shortcut])

# %% [markdown]
# ### 5. Build the model using the Functional API

# %%
def build_resnet_cifar(num_classes=10):
    inputs = tf.keras.Input(shape=(32, 32, 3), name="input")

    # Augmentation (only active during training — handled by model.fit)
    x = augment(inputs)

    # Stem: single 3×3 conv (no striding — CIFAR images are tiny)
    x = tf.keras.layers.Conv2D(64, 3, padding="same", use_bias=False, name="stem_conv")(x)

    # Stage 1: 64 → 128 filters, stride=2 to downsample 32→16
    x = residual_block(x, 128, stride=2, name="s1_b1")
    x = residual_block(x, 128, stride=1, name="s1_b2")

    # Stage 2: 128 → 256 filters, stride=2 → 16→8
    x = residual_block(x, 256, stride=2, name="s2_b1")
    x = residual_block(x, 256, stride=1, name="s2_b2")

    # Stage 3: 256 → 512 filters, stride=2 → 8→4
    x = residual_block(x, 512, stride=2, name="s3_b1")
    x = residual_block(x, 512, stride=1, name="s3_b2")

    # Final BN+ReLU (required for pre-activation variant)
    x = tf.keras.layers.BatchNormalization(name="final_bn")(x)
    x = tf.keras.layers.Activation("relu", name="final_relu")(x)

    # Classifier head
    x = tf.keras.layers.GlobalAveragePooling2D(name="gap")(x)
    x = tf.keras.layers.Dense(256, use_bias=False, name="fc1")(x)
    x = tf.keras.layers.BatchNormalization(name="fc_bn")(x)
    x = tf.keras.layers.Activation("relu", name="fc_relu")(x)
    x = tf.keras.layers.Dropout(0.4, name="dropout")(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    model = tf.keras.Model(inputs, outputs, name="resnet_cifar_v2")
    return model


model = build_resnet_cifar()
model.summary()
# Target param count: ~2.5M (vs Xception ~22M — tiny but deep)
# Out:
# Model: "resnet_cifar_v2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 32, 32, 3) │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augmentation        │ (None, 32, 32, 3) │          0 │ input[0][0]       │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 32, 32,    │      1,728 │ augmentation[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_bn1           │ (None, 32, 32,    │        256 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_relu1         │ (None, 32, 32,    │          0 │ s1_b1_bn1[0][0]   │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_conv1         │ (None, 16, 16,    │     73,728 │ s1_b1_relu1[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_bn2           │ (None, 16, 16,    │        512 │ s1_b1_conv1[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_relu2         │ (None, 16, 16,    │          0 │ s1_b1_bn2[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_conv2         │ (None, 16, 16,    │    147,456 │ s1_b1_relu2[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_proj (Conv2D) │ (None, 16, 16,    │      8,192 │ stem_conv[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b1_add (Add)     │ (None, 16, 16,    │          0 │ s1_b1_conv2[0][0… │
# │                     │ 128)              │            │ s1_b1_proj[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_bn1           │ (None, 16, 16,    │        512 │ s1_b1_add[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_relu1         │ (None, 16, 16,    │          0 │ s1_b2_bn1[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_conv1         │ (None, 16, 16,    │    147,456 │ s1_b2_relu1[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_bn2           │ (None, 16, 16,    │        512 │ s1_b2_conv1[0][0] │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_relu2         │ (None, 16, 16,    │          0 │ s1_b2_bn2[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_conv2         │ (None, 16, 16,    │    147,456 │ s1_b2_relu2[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s1_b2_add (Add)     │ (None, 16, 16,    │          0 │ s1_b2_conv2[0][0… │
# │                     │ 128)              │            │ s1_b1_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_bn1           │ (None, 16, 16,    │        512 │ s1_b2_add[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_relu1         │ (None, 16, 16,    │          0 │ s2_b1_bn1[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_conv1         │ (None, 8, 8, 256) │    294,912 │ s2_b1_relu1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_bn2           │ (None, 8, 8, 256) │      1,024 │ s2_b1_conv1[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_relu2         │ (None, 8, 8, 256) │          0 │ s2_b1_bn2[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_conv2         │ (None, 8, 8, 256) │    589,824 │ s2_b1_relu2[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_proj (Conv2D) │ (None, 8, 8, 256) │     32,768 │ s1_b2_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b1_add (Add)     │ (None, 8, 8, 256) │          0 │ s2_b1_conv2[0][0… │
# │                     │                   │            │ s2_b1_proj[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_bn1           │ (None, 8, 8, 256) │      1,024 │ s2_b1_add[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_relu1         │ (None, 8, 8, 256) │          0 │ s2_b2_bn1[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_conv1         │ (None, 8, 8, 256) │    589,824 │ s2_b2_relu1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_bn2           │ (None, 8, 8, 256) │      1,024 │ s2_b2_conv1[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_relu2         │ (None, 8, 8, 256) │          0 │ s2_b2_bn2[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_conv2         │ (None, 8, 8, 256) │    589,824 │ s2_b2_relu2[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s2_b2_add (Add)     │ (None, 8, 8, 256) │          0 │ s2_b2_conv2[0][0… │
# │                     │                   │            │ s2_b1_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_bn1           │ (None, 8, 8, 256) │      1,024 │ s2_b2_add[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_relu1         │ (None, 8, 8, 256) │          0 │ s3_b1_bn1[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_conv1         │ (None, 4, 4, 512) │  1,179,648 │ s3_b1_relu1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_bn2           │ (None, 4, 4, 512) │      2,048 │ s3_b1_conv1[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_relu2         │ (None, 4, 4, 512) │          0 │ s3_b1_bn2[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_conv2         │ (None, 4, 4, 512) │  2,359,296 │ s3_b1_relu2[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_proj (Conv2D) │ (None, 4, 4, 512) │    131,072 │ s2_b2_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b1_add (Add)     │ (None, 4, 4, 512) │          0 │ s3_b1_conv2[0][0… │
# │                     │                   │            │ s3_b1_proj[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_bn1           │ (None, 4, 4, 512) │      2,048 │ s3_b1_add[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_relu1         │ (None, 4, 4, 512) │          0 │ s3_b2_bn1[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_conv1         │ (None, 4, 4, 512) │  2,359,296 │ s3_b2_relu1[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_bn2           │ (None, 4, 4, 512) │      2,048 │ s3_b2_conv1[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_relu2         │ (None, 4, 4, 512) │          0 │ s3_b2_bn2[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_conv2         │ (None, 4, 4, 512) │  2,359,296 │ s3_b2_relu2[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ s3_b2_add (Add)     │ (None, 4, 4, 512) │          0 │ s3_b2_conv2[0][0… │
# │                     │                   │            │ s3_b1_add[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_bn            │ (None, 4, 4, 512) │      2,048 │ s3_b2_add[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_relu          │ (None, 4, 4, 512) │          0 │ final_bn[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 512)       │          0 │ final_relu[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1 (Dense)         │ (None, 256)       │    131,072 │ gap[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc_bn               │ (None, 256)       │      1,024 │ fc1[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc_relu             │ (None, 256)       │          0 │ fc_bn[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ fc_relu[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 10)        │      2,570 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,161,034 (42.58 MB)
#  Trainable params: 11,153,226 (42.55 MB)
#  Non-trainable params: 7,808 (30.50 KB)

# %% [markdown]
# ### 6. Learning rate schedule: Cosine decay with warm-up

# %%
EPOCHS     = 100
BATCH_SIZE = 128
STEPS_PER_EPOCH = math.ceil(len(x_train) / BATCH_SIZE)
WARMUP_EPOCHS   = 5

total_steps  = EPOCHS * STEPS_PER_EPOCH
warmup_steps = WARMUP_EPOCHS * STEPS_PER_EPOCH

# Cosine decay schedule (standard for ResNets on CIFAR)
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=0.1,
    decay_steps=total_steps - warmup_steps,
    alpha=1e-6
)

# Simple warmup wrapper
class WarmupCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, warmup_steps, schedule):
        self.warmup_steps = warmup_steps
        self.schedule = schedule

    def __call__(self, step):
        # Ramp from 0 → 0.1 over warmup, then cosine decay
        warmup_lr = 0.1 * tf.cast(step, tf.float32) / tf.cast(self.warmup_steps, tf.float32)
        cosine_lr = self.schedule(tf.maximum(step - self.warmup_steps, 0))
        return tf.cond(step < self.warmup_steps, lambda: warmup_lr, lambda: cosine_lr)

    def get_config(self):
        return {}

lr = WarmupCosineDecay(warmup_steps, lr_schedule)

# SGD with momentum is preferred over Adam for ResNets — better final accuracy
optimizer = tf.keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True)

# %% [markdown]
# ### 7. Compile with label smoothing (reduces overconfidence)

# %%
# label_smoothing requires one-hot labels (CategoricalCrossentropy),
# so we convert y from integer class indices to one-hot vectors.
NUM_CLASSES = 10
y_train_oh = tf.keras.utils.to_categorical(y_train, NUM_CLASSES)
y_val_oh   = tf.keras.utils.to_categorical(y_val,   NUM_CLASSES)
y_test_oh  = tf.keras.utils.to_categorical(y_test,  NUM_CLASSES)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=["accuracy"]
)

# %% [markdown]
# ### 8. Callbacks

# %%
callbacks = [
    # Save best weights
    tf.keras.callbacks.ModelCheckpoint(
        "best_resnet_cifar.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    ),
    # Early stopping with generous patience (cosine needs room to finish)
    tf.keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=20,
        restore_best_weights=True,
        verbose=1
    ),
    # TensorBoard (optional — remove if not using)
    # tf.keras.callbacks.TensorBoard(log_dir="./logs")
]

# %% [markdown]
# ### 9. Train

# %%
history = model.fit(
    x_train, y_train_oh,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(x_val, y_val_oh),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2708 - loss: 2.2383
# Epoch 1: val_accuracy improved from None to 0.43880, saving model to best_resnet_cifar.keras
#
# Epoch 1: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - accuracy: 0.3529 - loss: 1.9610 - val_accuracy: 0.4388 - val_loss: 1.7354
# Epoch 2/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4753 - loss: 1.6520
# Epoch 2: val_accuracy improved from 0.43880 to 0.44420, saving model to best_resnet_cifar.keras
#
# Epoch 2: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4893 - loss: 1.6182 - val_accuracy: 0.4442 - val_loss: 1.8496
# Epoch 3/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5427 - loss: 1.5068
# Epoch 3: val_accuracy did not improve from 0.44420
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.5560 - loss: 1.4828 - val_accuracy: 0.4034 - val_loss: 2.3040
# Epoch 4/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6011 - loss: 1.3975
# Epoch 4: val_accuracy improved from 0.44420 to 0.48560, saving model to best_resnet_cifar.keras
#
# Epoch 4: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.6092 - loss: 1.3845 - val_accuracy: 0.4856 - val_loss: 1.7581
# Epoch 5/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6453 - loss: 1.3077
# Epoch 5: val_accuracy improved from 0.48560 to 0.58000, saving model to best_resnet_cifar.keras
#
# Epoch 5: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6502 - loss: 1.2958 - val_accuracy: 0.5800 - val_loss: 1.4920
# Epoch 6/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6788 - loss: 1.2382
# Epoch 6: val_accuracy did not improve from 0.58000
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.6832 - loss: 1.2311 - val_accuracy: 0.5240 - val_loss: 1.7495
# Epoch 7/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7113 - loss: 1.1680
# Epoch 7: val_accuracy improved from 0.58000 to 0.60960, saving model to best_resnet_cifar.keras
#
# Epoch 7: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7161 - loss: 1.1611 - val_accuracy: 0.6096 - val_loss: 1.4346
# Epoch 8/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7361 - loss: 1.1170
# Epoch 8: val_accuracy improved from 0.60960 to 0.71040, saving model to best_resnet_cifar.keras
#
# Epoch 8: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.7385 - loss: 1.1133 - val_accuracy: 0.7104 - val_loss: 1.1553
# Epoch 9/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7557 - loss: 1.0814
# Epoch 9: val_accuracy improved from 0.71040 to 0.74120, saving model to best_resnet_cifar.keras
#
# Epoch 9: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7555 - loss: 1.0787 - val_accuracy: 0.7412 - val_loss: 1.0913
# Epoch 10/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7691 - loss: 1.0485
# Epoch 10: val_accuracy did not improve from 0.74120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7698 - loss: 1.0442 - val_accuracy: 0.7364 - val_loss: 1.0993
# Epoch 11/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7793 - loss: 1.0184
# Epoch 11: val_accuracy did not improve from 0.74120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7810 - loss: 1.0169 - val_accuracy: 0.7306 - val_loss: 1.1294
# Epoch 12/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7920 - loss: 0.9949
# Epoch 12: val_accuracy improved from 0.74120 to 0.75180, saving model to best_resnet_cifar.keras
#
# Epoch 12: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7916 - loss: 0.9937 - val_accuracy: 0.7518 - val_loss: 1.0741
# Epoch 13/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8012 - loss: 0.9711
# Epoch 13: val_accuracy did not improve from 0.75180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8025 - loss: 0.9685 - val_accuracy: 0.6978 - val_loss: 1.1962
# Epoch 14/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8106 - loss: 0.9503
# Epoch 14: val_accuracy improved from 0.75180 to 0.78320, saving model to best_resnet_cifar.keras
#
# Epoch 14: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8092 - loss: 0.9517 - val_accuracy: 0.7832 - val_loss: 1.0162
# Epoch 15/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8161 - loss: 0.9374
# Epoch 15: val_accuracy did not improve from 0.78320
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8167 - loss: 0.9358 - val_accuracy: 0.7744 - val_loss: 1.0202
# Epoch 16/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8302 - loss: 0.9094
# Epoch 16: val_accuracy did not improve from 0.78320
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8277 - loss: 0.9114 - val_accuracy: 0.7666 - val_loss: 1.0452
# Epoch 17/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8328 - loss: 0.9035
# Epoch 17: val_accuracy improved from 0.78320 to 0.80500, saving model to best_resnet_cifar.keras
#
# Epoch 17: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8331 - loss: 0.9022 - val_accuracy: 0.8050 - val_loss: 0.9582
# Epoch 18/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8415 - loss: 0.8786
# Epoch 18: val_accuracy did not improve from 0.80500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8398 - loss: 0.8837 - val_accuracy: 0.8006 - val_loss: 0.9542
# Epoch 19/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8448 - loss: 0.8723
# Epoch 19: val_accuracy improved from 0.80500 to 0.82320, saving model to best_resnet_cifar.keras
#
# Epoch 19: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8416 - loss: 0.8775 - val_accuracy: 0.8232 - val_loss: 0.9086
# Epoch 20/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8546 - loss: 0.8572
# Epoch 20: val_accuracy did not improve from 0.82320
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8526 - loss: 0.8603 - val_accuracy: 0.8022 - val_loss: 0.9636
# Epoch 21/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8566 - loss: 0.8457
# Epoch 21: val_accuracy improved from 0.82320 to 0.82640, saving model to best_resnet_cifar.keras
#
# Epoch 21: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8559 - loss: 0.8469 - val_accuracy: 0.8264 - val_loss: 0.9138
# Epoch 22/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8636 - loss: 0.8386
# Epoch 22: val_accuracy did not improve from 0.82640
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8615 - loss: 0.8405 - val_accuracy: 0.8142 - val_loss: 0.9302
# Epoch 23/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8685 - loss: 0.8198
# Epoch 23: val_accuracy improved from 0.82640 to 0.83560, saving model to best_resnet_cifar.keras
#
# Epoch 23: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8647 - loss: 0.8274 - val_accuracy: 0.8356 - val_loss: 0.8930
# Epoch 24/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8741 - loss: 0.8107
# Epoch 24: val_accuracy did not improve from 0.83560
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8700 - loss: 0.8165 - val_accuracy: 0.7942 - val_loss: 0.9579
# Epoch 25/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8770 - loss: 0.8046
# Epoch 25: val_accuracy improved from 0.83560 to 0.85040, saving model to best_resnet_cifar.keras
#
# Epoch 25: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.8745 - loss: 0.8073 - val_accuracy: 0.8504 - val_loss: 0.8560
# Epoch 26/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8784 - loss: 0.7956
# Epoch 26: val_accuracy did not improve from 0.85040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8784 - loss: 0.7980 - val_accuracy: 0.8438 - val_loss: 0.8591
# Epoch 27/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8826 - loss: 0.7909
# Epoch 27: val_accuracy did not improve from 0.85040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8807 - loss: 0.7931 - val_accuracy: 0.7780 - val_loss: 1.0251
# Epoch 28/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8862 - loss: 0.7795
# Epoch 28: val_accuracy did not improve from 0.85040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8848 - loss: 0.7823 - val_accuracy: 0.8246 - val_loss: 0.9098
# Epoch 29/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8911 - loss: 0.7722
# Epoch 29: val_accuracy did not improve from 0.85040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8884 - loss: 0.7762 - val_accuracy: 0.8248 - val_loss: 0.9183
# Epoch 30/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8935 - loss: 0.7611
# Epoch 30: val_accuracy did not improve from 0.85040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8922 - loss: 0.7657 - val_accuracy: 0.8136 - val_loss: 0.9486
# Epoch 31/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8944 - loss: 0.7590
# Epoch 31: val_accuracy did not improve from 0.85040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8960 - loss: 0.7582 - val_accuracy: 0.8358 - val_loss: 0.8806
# Epoch 32/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9003 - loss: 0.7500
# Epoch 32: val_accuracy improved from 0.85040 to 0.85440, saving model to best_resnet_cifar.keras
#
# Epoch 32: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.8978 - loss: 0.7523 - val_accuracy: 0.8544 - val_loss: 0.8417
# Epoch 33/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8995 - loss: 0.7503
# Epoch 33: val_accuracy did not improve from 0.85440
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.8999 - loss: 0.7484 - val_accuracy: 0.8460 - val_loss: 0.8574
# Epoch 34/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9022 - loss: 0.7413
# Epoch 34: val_accuracy did not improve from 0.85440
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9024 - loss: 0.7411 - val_accuracy: 0.8378 - val_loss: 0.8842
# Epoch 35/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9091 - loss: 0.7292
# Epoch 35: val_accuracy did not improve from 0.85440
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9072 - loss: 0.7317 - val_accuracy: 0.8526 - val_loss: 0.8367
# Epoch 36/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9084 - loss: 0.7287
# Epoch 36: val_accuracy did not improve from 0.85440
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9089 - loss: 0.7277 - val_accuracy: 0.8518 - val_loss: 0.8590
# Epoch 37/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9148 - loss: 0.7161
# Epoch 37: val_accuracy improved from 0.85440 to 0.86080, saving model to best_resnet_cifar.keras
#
# Epoch 37: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9131 - loss: 0.7202 - val_accuracy: 0.8608 - val_loss: 0.8258
# Epoch 38/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9155 - loss: 0.7119
# Epoch 38: val_accuracy did not improve from 0.86080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9158 - loss: 0.7127 - val_accuracy: 0.8524 - val_loss: 0.8502
# Epoch 39/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9194 - loss: 0.7044
# Epoch 39: val_accuracy improved from 0.86080 to 0.86400, saving model to best_resnet_cifar.keras
#
# Epoch 39: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9168 - loss: 0.7097 - val_accuracy: 0.8640 - val_loss: 0.8262
# Epoch 40/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9224 - loss: 0.6979
# Epoch 40: val_accuracy did not improve from 0.86400
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9209 - loss: 0.7015 - val_accuracy: 0.8626 - val_loss: 0.8232
# Epoch 41/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9236 - loss: 0.6934
# Epoch 41: val_accuracy improved from 0.86400 to 0.86840, saving model to best_resnet_cifar.keras
#
# Epoch 41: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9220 - loss: 0.6982 - val_accuracy: 0.8684 - val_loss: 0.8096
# Epoch 42/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9216 - loss: 0.6937
# Epoch 42: val_accuracy did not improve from 0.86840
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9222 - loss: 0.6942 - val_accuracy: 0.8586 - val_loss: 0.8354
# Epoch 43/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9286 - loss: 0.6822
# Epoch 43: val_accuracy improved from 0.86840 to 0.86980, saving model to best_resnet_cifar.keras
#
# Epoch 43: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9266 - loss: 0.6861 - val_accuracy: 0.8698 - val_loss: 0.8187
# Epoch 44/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9309 - loss: 0.6773
# Epoch 44: val_accuracy did not improve from 0.86980
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9288 - loss: 0.6813 - val_accuracy: 0.8642 - val_loss: 0.8195
# Epoch 45/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9319 - loss: 0.6768
# Epoch 45: val_accuracy did not improve from 0.86980
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9310 - loss: 0.6782 - val_accuracy: 0.8498 - val_loss: 0.8626
# Epoch 46/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9334 - loss: 0.6698
# Epoch 46: val_accuracy did not improve from 0.86980
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9335 - loss: 0.6710 - val_accuracy: 0.8214 - val_loss: 0.9268
# Epoch 47/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9361 - loss: 0.6637
# Epoch 47: val_accuracy did not improve from 0.86980
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9362 - loss: 0.6658 - val_accuracy: 0.8670 - val_loss: 0.8211
# Epoch 48/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9400 - loss: 0.6598
# Epoch 48: val_accuracy improved from 0.86980 to 0.88080, saving model to best_resnet_cifar.keras
#
# Epoch 48: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9380 - loss: 0.6632 - val_accuracy: 0.8808 - val_loss: 0.7729
# Epoch 49/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9438 - loss: 0.6502
# Epoch 49: val_accuracy did not improve from 0.88080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9409 - loss: 0.6557 - val_accuracy: 0.8670 - val_loss: 0.8188
# Epoch 50/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9433 - loss: 0.6495
# Epoch 50: val_accuracy did not improve from 0.88080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9414 - loss: 0.6529 - val_accuracy: 0.8734 - val_loss: 0.8052
# Epoch 51/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9423 - loss: 0.6489
# Epoch 51: val_accuracy did not improve from 0.88080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9415 - loss: 0.6509 - val_accuracy: 0.8608 - val_loss: 0.8360
# Epoch 52/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9453 - loss: 0.6433
# Epoch 52: val_accuracy did not improve from 0.88080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9441 - loss: 0.6475 - val_accuracy: 0.8806 - val_loss: 0.7897
# Epoch 53/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9481 - loss: 0.6395
# Epoch 53: val_accuracy improved from 0.88080 to 0.89160, saving model to best_resnet_cifar.keras
#
# Epoch 53: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9475 - loss: 0.6407 - val_accuracy: 0.8916 - val_loss: 0.7612
# Epoch 54/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9502 - loss: 0.6338
# Epoch 54: val_accuracy did not improve from 0.89160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9501 - loss: 0.6334 - val_accuracy: 0.8782 - val_loss: 0.7974
# Epoch 55/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9530 - loss: 0.6272
# Epoch 55: val_accuracy did not improve from 0.89160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9493 - loss: 0.6335 - val_accuracy: 0.8840 - val_loss: 0.7799
# Epoch 56/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9534 - loss: 0.6277
# Epoch 56: val_accuracy did not improve from 0.89160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9533 - loss: 0.6272 - val_accuracy: 0.8848 - val_loss: 0.7768
# Epoch 57/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9540 - loss: 0.6247
# Epoch 57: val_accuracy did not improve from 0.89160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9541 - loss: 0.6242 - val_accuracy: 0.8836 - val_loss: 0.7823
# Epoch 58/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9599 - loss: 0.6157
# Epoch 58: val_accuracy did not improve from 0.89160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9563 - loss: 0.6213 - val_accuracy: 0.8868 - val_loss: 0.7800
# Epoch 59/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9578 - loss: 0.6159
# Epoch 59: val_accuracy improved from 0.89160 to 0.89480, saving model to best_resnet_cifar.keras
#
# Epoch 59: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9576 - loss: 0.6170 - val_accuracy: 0.8948 - val_loss: 0.7563
# Epoch 60/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9591 - loss: 0.6115
# Epoch 60: val_accuracy did not improve from 0.89480
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9595 - loss: 0.6121 - val_accuracy: 0.8892 - val_loss: 0.7578
# Epoch 61/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9631 - loss: 0.6068
# Epoch 61: val_accuracy did not improve from 0.89480
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9615 - loss: 0.6092 - val_accuracy: 0.8940 - val_loss: 0.7522
# Epoch 62/100
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9626 - loss: 0.6068
# Epoch 62: val_accuracy did not improve from 0.89480
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9628 - loss: 0.6053 - val_accuracy: 0.8882 - val_loss: 0.7817
# Epoch 63/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9660 - loss: 0.6013
# Epoch 63: val_accuracy did not improve from 0.89480
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9653 - loss: 0.6006 - val_accuracy: 0.8910 - val_loss: 0.7710
# Epoch 64/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9647 - loss: 0.5996
# Epoch 64: val_accuracy did not improve from 0.89480
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9650 - loss: 0.6001 - val_accuracy: 0.8874 - val_loss: 0.7810
# Epoch 65/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9695 - loss: 0.5911
# Epoch 65: val_accuracy improved from 0.89480 to 0.89560, saving model to best_resnet_cifar.keras
#
# Epoch 65: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9677 - loss: 0.5940 - val_accuracy: 0.8956 - val_loss: 0.7605
# Epoch 66/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9697 - loss: 0.5912
# Epoch 66: val_accuracy improved from 0.89560 to 0.89660, saving model to best_resnet_cifar.keras
#
# Epoch 66: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9693 - loss: 0.5920 - val_accuracy: 0.8966 - val_loss: 0.7501
# Epoch 67/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9695 - loss: 0.5894
# Epoch 67: val_accuracy did not improve from 0.89660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9694 - loss: 0.5889 - val_accuracy: 0.8898 - val_loss: 0.7679
# Epoch 68/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9730 - loss: 0.5829
# Epoch 68: val_accuracy improved from 0.89660 to 0.89720, saving model to best_resnet_cifar.keras
#
# Epoch 68: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9716 - loss: 0.5856 - val_accuracy: 0.8972 - val_loss: 0.7517
# Epoch 69/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9720 - loss: 0.5842
# Epoch 69: val_accuracy improved from 0.89720 to 0.89920, saving model to best_resnet_cifar.keras
#
# Epoch 69: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9714 - loss: 0.5850 - val_accuracy: 0.8992 - val_loss: 0.7479
# Epoch 70/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9749 - loss: 0.5799
# Epoch 70: val_accuracy improved from 0.89920 to 0.90000, saving model to best_resnet_cifar.keras
#
# Epoch 70: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9733 - loss: 0.5820 - val_accuracy: 0.9000 - val_loss: 0.7443
# Epoch 71/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9744 - loss: 0.5780
# Epoch 71: val_accuracy improved from 0.90000 to 0.90660, saving model to best_resnet_cifar.keras
#
# Epoch 71: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9738 - loss: 0.5807 - val_accuracy: 0.9066 - val_loss: 0.7335
# Epoch 72/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9761 - loss: 0.5757
# Epoch 72: val_accuracy did not improve from 0.90660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9754 - loss: 0.5777 - val_accuracy: 0.9028 - val_loss: 0.7424
# Epoch 73/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9764 - loss: 0.5735
# Epoch 73: val_accuracy did not improve from 0.90660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9762 - loss: 0.5737 - val_accuracy: 0.9040 - val_loss: 0.7348
# Epoch 74/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9784 - loss: 0.5703
# Epoch 74: val_accuracy did not improve from 0.90660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9776 - loss: 0.5723 - val_accuracy: 0.9002 - val_loss: 0.7441
# Epoch 75/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9771 - loss: 0.5718
# Epoch 75: val_accuracy did not improve from 0.90660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9777 - loss: 0.5713 - val_accuracy: 0.9038 - val_loss: 0.7354
# Epoch 76/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9793 - loss: 0.5681
# Epoch 76: val_accuracy did not improve from 0.90660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9792 - loss: 0.5681 - val_accuracy: 0.9030 - val_loss: 0.7367
# Epoch 77/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9812 - loss: 0.5636
# Epoch 77: val_accuracy did not improve from 0.90660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9803 - loss: 0.5648 - val_accuracy: 0.9058 - val_loss: 0.7353
# Epoch 78/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9804 - loss: 0.5657
# Epoch 78: val_accuracy improved from 0.90660 to 0.90700, saving model to best_resnet_cifar.keras
#
# Epoch 78: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9802 - loss: 0.5652 - val_accuracy: 0.9070 - val_loss: 0.7300
# Epoch 79/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9813 - loss: 0.5634
# Epoch 79: val_accuracy did not improve from 0.90700
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9802 - loss: 0.5654 - val_accuracy: 0.9048 - val_loss: 0.7340
# Epoch 80/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9828 - loss: 0.5613
# Epoch 80: val_accuracy did not improve from 0.90700
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9826 - loss: 0.5608 - val_accuracy: 0.9060 - val_loss: 0.7303
# Epoch 81/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9834 - loss: 0.5593
# Epoch 81: val_accuracy improved from 0.90700 to 0.90740, saving model to best_resnet_cifar.keras
#
# Epoch 81: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9825 - loss: 0.5607 - val_accuracy: 0.9074 - val_loss: 0.7364
# Epoch 82/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9832 - loss: 0.5575
# Epoch 82: val_accuracy did not improve from 0.90740
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9832 - loss: 0.5583 - val_accuracy: 0.9052 - val_loss: 0.7328
# Epoch 83/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9842 - loss: 0.5574
# Epoch 83: val_accuracy did not improve from 0.90740
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9837 - loss: 0.5583 - val_accuracy: 0.9064 - val_loss: 0.7361
# Epoch 84/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9843 - loss: 0.5565
# Epoch 84: val_accuracy did not improve from 0.90740
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9834 - loss: 0.5578 - val_accuracy: 0.9062 - val_loss: 0.7315
# Epoch 85/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9843 - loss: 0.5571
# Epoch 85: val_accuracy did not improve from 0.90740
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9848 - loss: 0.5556 - val_accuracy: 0.9066 - val_loss: 0.7326
# Epoch 86/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9842 - loss: 0.5573
# Epoch 86: val_accuracy improved from 0.90740 to 0.91040, saving model to best_resnet_cifar.keras
#
# Epoch 86: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9844 - loss: 0.5575 - val_accuracy: 0.9104 - val_loss: 0.7245
# Epoch 87/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9843 - loss: 0.5549
# Epoch 87: val_accuracy did not improve from 0.91040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9842 - loss: 0.5553 - val_accuracy: 0.9078 - val_loss: 0.7262
# Epoch 88/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9856 - loss: 0.5534
# Epoch 88: val_accuracy did not improve from 0.91040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9851 - loss: 0.5542 - val_accuracy: 0.9078 - val_loss: 0.7273
# Epoch 89/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9862 - loss: 0.5540
# Epoch 89: val_accuracy did not improve from 0.91040
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9866 - loss: 0.5532 - val_accuracy: 0.9088 - val_loss: 0.7276
# Epoch 90/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9866 - loss: 0.5527
# Epoch 90: val_accuracy improved from 0.91040 to 0.91080, saving model to best_resnet_cifar.keras
#
# Epoch 90: finished saving model to best_resnet_cifar.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9859 - loss: 0.5531 - val_accuracy: 0.9108 - val_loss: 0.7236
# Epoch 91/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9861 - loss: 0.5524
# Epoch 91: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9864 - loss: 0.5518 - val_accuracy: 0.9096 - val_loss: 0.7215
# Epoch 92/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9867 - loss: 0.5508
# Epoch 92: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9868 - loss: 0.5511 - val_accuracy: 0.9104 - val_loss: 0.7230
# Epoch 93/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9869 - loss: 0.5524
# Epoch 93: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9865 - loss: 0.5518 - val_accuracy: 0.9098 - val_loss: 0.7252
# Epoch 94/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9872 - loss: 0.5503
# Epoch 94: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9865 - loss: 0.5514 - val_accuracy: 0.9094 - val_loss: 0.7246
# Epoch 95/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9881 - loss: 0.5489
# Epoch 95: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9872 - loss: 0.5500 - val_accuracy: 0.9090 - val_loss: 0.7248
# Epoch 96/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9864 - loss: 0.5506
# Epoch 96: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9868 - loss: 0.5496 - val_accuracy: 0.9084 - val_loss: 0.7247
# Epoch 97/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9865 - loss: 0.5512
# Epoch 97: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9861 - loss: 0.5520 - val_accuracy: 0.9088 - val_loss: 0.7247
# Epoch 98/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9861 - loss: 0.5518
# Epoch 98: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9869 - loss: 0.5504 - val_accuracy: 0.9090 - val_loss: 0.7248
# Epoch 99/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9874 - loss: 0.5497
# Epoch 99: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9874 - loss: 0.5501 - val_accuracy: 0.9090 - val_loss: 0.7239
# Epoch 100/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9868 - loss: 0.5507
# Epoch 100: val_accuracy did not improve from 0.91080
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9866 - loss: 0.5511 - val_accuracy: 0.9090 - val_loss: 0.7250
# Restoring model weights from the end of the best epoch: 90.

# %% [markdown]
# ### 10. Evaluate

# %%
test_loss, test_acc = model.evaluate(x_test, y_test_oh, verbose=2)
print(f"\nTest Accuracy (ResNet CNN v2): {test_acc*100:.2f}%")
print(f"Baseline v1 accuracy:          74.03%")
print(f"Improvement:                   +{(test_acc - 0.7403)*100:.2f}%")
# Out:
# 313/313 - 1s - 4ms/step - accuracy: 0.9027 - loss: 0.7421
#
# Test Accuracy (ResNet CNN v2): 90.27%
# Baseline v1 accuracy:          74.03%
# Improvement:                   +16.24%

# %% [markdown]
# ### 11. Training curves

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(history.history["accuracy"],     label="Train acc")
ax1.plot(history.history["val_accuracy"], label="Val acc")
ax1.set_title("Accuracy"); ax1.legend(); ax1.set_xlabel("Epoch")

ax2.plot(history.history["loss"],     label="Train loss")
ax2.plot(history.history["val_loss"], label="Val loss")
ax2.set_title("Loss"); ax2.legend(); ax2.set_xlabel("Epoch")

plt.tight_layout()
plt.savefig("training_curves_v2.png", dpi=150)
plt.show()
